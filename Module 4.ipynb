# %% [markdown]
# ### Scaling Data Analysis
#
# #### 1. Fast Random Access?
# A lot of programs are OOP
# ![image.png](attachment:image.png)

# %% [markdown]
# To mitigate this problem, store the object directly. Use Datastore, goes to pedabyte of data. (Persistent Hashmap, Filter obects on property, put object, attribute, structured data from AppEngine apps)![image.png](attachment:image.png)

# %% [markdown]
# TO interact with Datastore, its different from the sql
#
# Use ofy.save().entity(xjin) objectify![image.png](attachment:image.png)

# %% [markdown]
# Use of Datalab to take advantage of BigQuery and use Google API
#
# #### Some of the existing code is in the datalab Lab4c for all the APIs
