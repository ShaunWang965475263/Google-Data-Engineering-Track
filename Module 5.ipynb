# %% [markdown]
# ### Asychronous processing
# Data Track Asychronous processing to absorb shock and change
# Example: A server that can serve 100 people suddenly have 4000 users

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
