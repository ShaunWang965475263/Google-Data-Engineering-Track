# %% [markdown]
# ### CPU On Demand
#
# GCP is composed of two things: Cloud Storage and Cloud Computing.
# Working as a Data Engieering, the daily work is probably not around the infrastracture.
#
# A virtual machine, you can specificify how many CPU cores you need, how much memory you need. And each of the machine contains load balancing, advanced network, monitoring, clsutering, container support etc. The pricing is charged for the minute you use.
#
# Preemption is the act of temporarily interrupting a task being carried out by a computer system

# %% [markdown]
# #### Lab 2a
#
# Create a Compute Engine Instance : https://codelabs.developers.google.com/codelabs/cpb100-compute-engine/#2
#
# SSH into the instance
#
# Install the software package git.
#
# Created a new account and password for the free tier.

# %% [markdown]
# Once you get the instance set up, you can find your VM and code in secure shell and install git

# %% [markdown]
# ### Cloud storage
#
# ![image.png](attachment:image.png)
# Use a compute engine VM, once the data is computed, it goes on to be stored
# The simplest way to add data to the cloud is to use gsutil cp(copy)
# Or alternatively, use GCP Console, REST API
#
# gs(Google Storage)://acme-sales/data/ (Concept of Bucket, like a domain name)
# rv: remove, mv: move, ls: list, mb: make a bucket, rb: remove a bucket rsync: upload changed files. acl: access control list.
#
# #### Data Handling
# Transfer Service can be set up from GCP to transfer from S3
#
# Staging Area: used for Queries AND Analysis.Control access
# #### Lantency with zones and region
# Find the closest zone and region where most users are. The reason to choose different zones and regions, distribute the data across zones to reduce service disruptions. Multiple servers in a region = less disruptions. Multiple regions to avoid servers go down.

# %% [markdown]
# #### Lab2b Interact with Cloud Storage
# ![image.png](attachment:image.png)
#
# https://codelabs.developers.google.com/codelabs/cpb100-cloud-storage/#2
#
# less ingest.sh; bash ingest.sh to download the file; head (file.csv)
#
# First, View: wget http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.csv -O earthquakes.csv
#
# Then bash (download) ingest.sh
# Then install missing libraries in python:
#
# sudo apt-get update
# sudo apt-get --fix-missing install python-mpltoolkits.basemap python-numpy python-matplotlib
#
# Run the python code below to Transform. After that create a bucket: bucket965475263, name of the bucket must be unique
# Once in the ssh, you have done gsutil cp Earthquakes.* gs://bucketbucket965475263,  you can share publicly.

# %% [markdown]
#  #### You can also play with Cloud Shell by Activating it. 5Gigs.
