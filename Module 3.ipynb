# %% [markdown]
# ### Data Analysis Using MySQL and Tools in Hadoop Ecosystem
#
# Snapchat runs completely on AppEngine..
#
# #### What is an App Engine?
#
# Google App Engine is a web framework and cloud computing platform for developing and hosting web applications in Google-managed data centers. Applications are sandboxed and run across multiple servers. Wikipedia
#
# #### What is a container Enginine?
#
# Google Kubernetes Engine (GKE) is a management and orchestration system for Docker container and container clusters that run within Google's public cloud services.Dec 30, 2015
#
# #### What is a compute engine?
#
# Google Compute Engine is the Infrastructure as a Service component of Google Cloud Platform which is built on the global infrastructure that runs Google’s search engine, Gmail, YouTube and other services. Wikipedia
#
#
# ![image.png](attachment:image.png)
#
# #### Machine Learning
#
# If you want to teach a neural network to recognize a cat, for instance, you don't tell it to look for whiskers, fur, eyes, you simply show them millions of images and eventually they will get it.
#
# #### How does a Recommendation System work?
#
# Ratings, user rate a few houses explicitly(Maybe after an open house) or implicitly (A user clicked on a link to the house).
#
# Training, a machine learning model
#
# Recommendation, for each user, the model is applied to every unrated house and the top 5 houses for that user are served.

# %% [markdown]
# ### How do you predict the model?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://codelabs.developers.google.com/codelabs/cpb100-cloud-sql/#7 How to use CloudSQL
#
# The main component in connecting the SQL and the VM is to use the IP address from the VM (./find_my_ip.sh) and add to the network of Google SQL. Furthermore, when running the SQL command in the command line, need to use
# mysql --host=(ip address of the SQL instance) --user=root --password. Password will be prompted.

# %% [markdown]
# ### What is Hadoop?
# ![image.png](attachment:image.png)
#
# #### What is Dataproc
# Google managed Hadoop, Pig, Hive, Spark
#
# Image versioning, Resize in seconds, Automated cluster mgmt, Familiar, Integrates with GCP, Flexible VM, Google Security
#
# The reason why DataProc is better is because DataCluster doesn't need to be paid when not using.
#
# https://codelabs.developers.google.com/codelabs/cpb100-dataproc/#0 Recommendation ML with DataProc

# %% [markdown]
# #### First create an instance in DataProc.
#
# Authorize your cloudshell:
# #!/bin/bash
# gcloud sql instances patch rentals \
#     --authorized-networks `wget -qO - http://ipecho.net/plain`/32
#
# Authorize your dataproc https://github.com/GoogleCloudPlatform/training-data-analyst/blob/master/CPB100/lab3b/authorize_dataproc.sh
#
# Connect to your Cloud SQL instance: mysql --host=<MySQLIP> --user=root --password/
#     After that, use (database)
#
#     Once the database is connected, simply use SQL

# %% [markdown]
# wzx950505 password to google sql
#
# 35.196.251.79 find_my_ip.sh
#
# 35.225.29.79  mysql public ip.
